# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.keras import Sequential, layers, callbacks
from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional

# %%
# Load and preprocess the data
df = pd.read_csv(r"D:\MCA\RBL\Final paper\new RBL\MY paper\Data\ICICIBANK.csv", parse_dates=['Date'], index_col='Date')
df = df.loc[:, ~df.columns.isin(['Series','Trades', 'Deliverable Volume', '%Deliverble'])]

train_size = int(len(df) * 0.8)
train_size1 = int(len(df) * 0.64)
train_size2 = int(len(df) * 0.25)
train_dataset, test_dataset = df.iloc[train_size2:train_size1], df.iloc[train_size1:train_size]

# Split train data to X and y
X_train = train_dataset.drop('Open', axis=1)
y_train = train_dataset.loc[:, ['Open']]

# Split test data to X and y
test_x = test_dataset.drop('Open', axis=1)
test_y = test_dataset.loc[:, ['Open']]

numerical_cols = ['Open', 'High', 'Low', 'Close', 'Volume', 'Turnover']
df[numerical_cols] = MinMaxScaler().fit_transform(df[numerical_cols])

train_data, test_data = train_test_split(df, test_size=0.2, shuffle=False)

X_train = train_data.drop(columns=['Symbol'] + numerical_cols)
y_train = train_data['Open']
X_test = test_data.drop(columns=['Symbol'] + numerical_cols)
y_test = test_data['Open']

scaler_x = MinMaxScaler(feature_range=(0, 1))
scaler_y = MinMaxScaler(feature_range=(0, 1))

train_x_norm = scaler_x.fit_transform(X_train)
train_y_norm = scaler_y.fit_transform(y_train.values.reshape(-1, 1)) # convert to numpy array and reshape
test_x_norm = scaler_x.transform(X_test)
test_y_norm = scaler_y.transform(y_test.values.reshape(-1, 1))

def create_dataset(X, y, time_steps=1):
    Xs, ys = [], []
    
    for i in range(len(X)-time_steps):
        v = X[i:i+time_steps, :]
        Xs.append(v)
        ys.append(y[i+time_steps])
        
    return np.array(Xs), np.array(ys)

TIME_STEPS = 30

X_test, y_test = create_dataset(test_x_norm, test_y_norm, TIME_STEPS)
X_train, y_train = create_dataset(train_x_norm, train_y_norm, TIME_STEPS)
print('X_train.shape:', X_train.shape)
print('y_train.shape:', y_train.shape)
print('X_test.shape:', X_test.shape)
print('y_test.shape:', y_test.shape)
# Out:
# X_train.shape: (4214, 30, 3)
# y_train.shape: (4214, 1)
# X_test.shape: (1032, 30, 3)
# y_test.shape: (1032, 1)

# %%
# Adaptive Genetic Algorithm
class AdaptiveGeneticAlgorithm:
    def __init__(self, population_size, num_genes, fitness_func):
        self.population_size = population_size
        self.num_genes = num_genes
        self.fitness_func = fitness_func
        self.population = np.random.uniform(low=0, high=1, size=(population_size, num_genes))
        self.best_individual = None
        self.best_fitness = None
    
    def evaluate_fitness(self):
        fitness_values = []
        for individual in self.population:
            fitness_values.append(self.fitness_func(individual))
        return np.array(fitness_values)
    
    def selection(self, fitness_values, num_parents):
        sorted_indices = np.argsort(fitness_values)
        parents = self.population[sorted_indices[:num_parents]]
        if parents.shape[0] == 0:
            parents = self.population[:1]  # Select one random parent if no parents were selected
        return parents
    
    def crossover(self, parents, offspring_size):
        offspring = np.empty(offspring_size)
        crossover_point = np.random.randint(low=0, high=self.num_genes)
        for i in range(offspring_size[0]):
            parent1_idx = i % parents.shape[0]
            parent2_idx = (i+1) % parents.shape[0]
            offspring[i, :crossover_point] = parents[parent1_idx, :crossover_point]
            offspring[i, crossover_point:] = parents[parent2_idx, crossover_point:]
        return offspring
    
    def mutation(self, offspring):
        mutation_rate = 1 / self.num_genes
        for i in range(offspring.shape[0]):
            for j in range(offspring.shape[1]):
                if np.random.uniform() < mutation_rate:
                    offspring[i, j] = np.random.uniform(low=0, high=1)
        return offspring
    
    def optimize(self, num_generations):
        for generation in range(num_generations):
            fitness_values = self.evaluate_fitness()
            best_fitness_idx = np.argmin(fitness_values)
            best_fitness = fitness_values[best_fitness_idx]
            best_individual = self.population[best_fitness_idx]
            
            if self.best_fitness is None or best_fitness < self.best_fitness:
                self.best_fitness = best_fitness
                self.best_individual = best_individual
            
            parents = self.selection(fitness_values, num_parents=self.population_size//2)
            offspring = self.crossover(parents, offspring_size=(self.population_size-parents.shape[0], self.num_genes))
            offspring = self.mutation(offspring)
            
            self.population = np.concatenate((parents, offspring))
            
            print(f"Generation: {generation+1}")
            print(f"Best Fitness: {best_fitness}")
            print(f"Best Individual: {best_individual}")
            print("----------------------")
            
        print("Final Result:")
        print(f"Best Fitness: {self.best_fitness}")
        print(f"Best Individual: {self.best_individual}")
        return self.best_individual, self.best_fitness

# %%
def fitness_function(individual):
    lstm_units = int(individual[0] * 100) + 1
    
    model = Sequential()
    model.add(Bidirectional(LSTM(units=lstm_units, return_sequences=True), input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(Bidirectional(LSTM(units=lstm_units)))
    model.add(Dense(1))
    model.compile(loss='mse', optimizer='adam')
    
    # Fit the model and get the predictions
    model, history, train_predictions, test_predictions = fit_model(model, X_train, y_train, X_test, y_test)
    
    # Inverse transform the normalized predictions and true values
    train_predictions = scaler_y.inverse_transform(train_predictions)
    test_predictions = scaler_y.inverse_transform(test_predictions)
    y_train_true = scaler_y.inverse_transform(y_train)
    y_test_true = scaler_y.inverse_transform(y_test)
    
    # Calculate the mean squared error
    train_mse = np.mean(np.square(train_predictions - y_train_true))
    test_mse = np.mean(np.square(test_predictions - y_test_true))
    
    return test_mse

def fit_model(model, X_train, y_train, X_test, y_test):
    early_stop = callbacks.EarlyStopping(monitor='val_loss', patience=10)
    history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test),
                        shuffle=False, callbacks=[early_stop])
    
    # Get the predictions for training and test data
    train_predictions = model.predict(X_train)
    test_predictions = model.predict(X_test)
    
    return model, history, train_predictions, test_predictions

# %%
# Create and run the Adaptive Genetic Algorithm
population_size = 10
num_genes = 5
num_generations = 10

ga = AdaptiveGeneticAlgorithm(population_size, num_genes, fitness_function)
best_individual, best_fitness = ga.optimize(num_generations)
lstm_units = int(best_individual[0] * 100) + 1
# Out:
# Epoch 1/100
# 132/132 [==============================] - 13s 64ms/step - loss: 0.0033 - val_loss: 0.0100
# Epoch 2/100
# 132/132 [==============================] - 7s 56ms/step - loss: 0.0102 - val_loss: 0.0101
# Epoch 3/100
# 132/132 [==============================] - 7s 56ms/step - loss: 0.0050 - val_loss: 0.0029
# Epoch 4/100
# 132/132 [==============================] - 7s 56ms/step - loss: 0.0022 - val_loss: 7.5661e-04
# Epoch 5/100
# 132/132 [==============================] - 7s 56ms/step - loss: 8.0567e-04 - val_loss: 7.2974e-05
# Epoch 6/100
# 132/132 [==============================] - 8s 58ms/step - loss: 4.3079e-04 - val_loss: 5.3592e-05
# Epoch 7/100
# 132/132 [==============================] - 8s 57ms/step - loss: 5.5498e-04 - val_loss: 8.4817e-05
# Epoch 8/100
# 132/132 [==============================] - 8s 57ms/step - loss: 4.2200e-04 - val_loss: 4.9048e-05
# Epoch 9/100
# 132/132 [==============================] - 7s 56ms/step - loss: 4.9441e-04 - val_loss: 7.5763e-05
# Epoch 10/100
# 132/132 [==============================] - 7s 55ms/step - loss: 4.9932e-04 - val_loss: 3.4249e-05
# Epoch 11/100
# 132/132 [==============================] - 7s 56ms/step - loss: 4.6268e-04 - val_loss: 3.3995e-05
# Epoch 12/100
# 132/132 [==============================] - 8s 57ms/step - loss: 4.4640e-04 - val_loss: 6.0012e-05
# Epoch 13/100
# 132/132 [==============================] - 7s 55ms/step - loss: 4.5183e-04 - val_loss: 9.2278e-05
# Epoch 14/100
# 132/132 [==============================] - 7s 56ms/step - loss: 4.6101e-04 - val_loss: 1.4517e-04
# Epoch 15/100
# 132/132 [==============================] - 7s 56ms/step - loss: 4.5993e-04 - val_loss: 2.1142e-04
# Epoch 16/100
# 132/132 [==============================] - 7s 57ms/step - loss: 4.5262e-04 - val_loss: 2.6181e-04
# Epoch 17/100
# 132/132 [==============================] - 7s 55ms/step - loss: 4.4792e-04 - val_loss: 2.9342e-04
# Epoch 18/100
# 132/132 [==============================] - 7s 55ms/step - loss: 4.4571e-04 - val_loss: 3.2142e-04
# Epoch 19/100
# 132/132 [==============================] - 7s 54ms/step - loss: 4.4195e-04 - val_loss: 3.4793e-04
# Epoch 20/100
# 132/132 [==============================] - 7s 55ms/step - loss: 4.3599e-04 - val_loss: 3.6810e-04
# Epoch 21/100
# 132/132 [==============================] - 7s 53ms/step - loss: 4.2988e-04 - val_loss: 3.8288e-04
# 132/132 [==============================] - 3s 13ms/step
# 33/33 [==============================] - 0s 12ms/step
# Epoch 1/100
# 132/132 [==============================] - 9s 33ms/step - loss: 0.0060 - val_loss: 0.0083
# Epoch 2/100
# 132/132 [==============================] - 3s 23ms/step - loss: 0.0042 - val_loss: 0.0034
# Epoch 3/100
# 132/132 [==============================] - 3s 23ms/step - loss: 0.0020 - val_loss: 9.0198e-04
# Epoch 4/100
# 132/132 [==============================] - 3s 23ms/step - loss: 7.5028e-04 - val_loss: 8.1320e-04
# Epoch 5/100
# 132/132 [==============================] - 3s 23ms/step - loss: 0.0018 - val_loss: 5.4130e-04
# Epoch 6/100
# 132/132 [==============================] - 3s 23ms/step - loss: 6.0311e-04 - val_loss: 6.4646e-05
# Epoch 7/100
# 132/132 [==============================] - 3s 23ms/step - loss: 8.1113e-04 - val_loss: 2.1614e-04
# Epoch 8/100
# 132/132 [==============================] - 3s 23ms/step - loss: 6.4614e-04 - val_loss: 5.5875e-05
# Epoch 9/100
# 132/132 [==============================] - 3s 23ms/step - loss: 5.4742e-04 - val_loss: 7.5059e-05
# Epoch 10/100
# 132/132 [==============================] - 3s 23ms/step - loss: 5.3973e-04 - val_loss: 8.5066e-05
# Epoch 11/100
# 132/132 [==============================] - 3s 23ms/step - loss: 5.7194e-04 - val_loss: 1.2583e-04
# Epoch 12/100
# 132/132 [==============================] - 3s 23ms/step - loss: 5.4089e-04 - val_loss: 2.5476e-04
# Epoch 13/100
# 132/132 [==============================] - 3s 23ms/step - loss: 4.9769e-04 - val_loss: 2.7674e-04
# Epoch 14/100
# 132/132 [==============================] - 3s 24ms/step - loss: 4.9530e-04 - val_loss: 2.4657e-04
# Epoch 15/100
# 132/132 [==============================] - 3s 24ms/step - loss: 4.9917e-04 - val_loss: 2.8625e-04
# Epoch 16/100
# 132/132 [==============================] - 3s 24ms/step - loss: 4.7693e-04 - val_loss: 3.3626e-04
# Epoch 17/100
# 132/132 [==============================] - 3s 24ms/step - loss: 4.6033e-04 - val_loss: 3.2745e-04
# Epoch 18/100
# 132/132 [==============================] - 3s 23ms/step - loss: 4.5012e-04 - val_loss: 3.2812e-04
# 132/132 [==============================] - 2s 7ms/step
# 33/33 [==============================] - 0s 7ms/step
# Epoch 1/100
# 132/132 [==============================] - 12s 51ms/step - loss: 0.0060 - val_loss: 0.0059
# Epoch 2/100
# 132/132 [==============================] - 5s 38ms/step - loss: 0.0052 - val_loss: 0.0038
# Epoch 3/100
# 132/132 [==============================] - 5s 38ms/step - loss: 0.0016 - val_loss: 6.7940e-04
# Epoch 4/100
# 132/132 [==============================] - 5s 38ms/step - loss: 7.3918e-04 - val_loss: 5.1500e-04
# Epoch 5/100
# 132/132 [==============================] - 5s 37ms/step - loss: 0.0014 - val_loss: 2.3871e-04
# Epoch 6/100
# 132/132 [==============================] - 5s 37ms/step - loss: 5.8668e-04 - val_loss: 3.7200e-05
# Epoch 7/100
# 132/132 [==============================] - 5s 37ms/step - loss: 7.0044e-04 - val_loss: 1.0962e-04
# Epoch 8/100
# 132/132 [==============================] - 5s 38ms/step - loss: 7.6829e-04 - val_loss: 5.9498e-05
# Epoch 9/100
# 132/132 [==============================] - 5s 37ms/step - loss: 5.4923e-04 - val_loss: 1.4354e-04
# Epoch 10/100
# 132/132 [==============================] - 5s 37ms/step - loss: 5.2290e-04 - val_loss: 1.3025e-04
# Epoch 11/100
# 132/132 [==============================] - 5s 37ms/step - loss: 5.7610e-04 - val_loss: 1.7838e-04
# Epoch 12/100
# 132/132 [==============================] - 5s 37ms/step - loss: 5.7791e-04 - val_loss: 3.6676e-04
# Epoch 13/100
# 132/132 [==============================] - 5s 37ms/step - loss: 5.1340e-04 - val_loss: 3.9630e-04
# Epoch 14/100
# 132/132 [==============================] - 5s 37ms/step - loss: 5.0339e-04 - val_loss: 3.6264e-04
# Epoch 15/100
# 132/132 [==============================] - 5s 37ms/step - loss: 5.0891e-04 - val_loss: 4.1894e-04
# Epoch 16/100
# 132/132 [==============================] - 5s 37ms/step - loss: 4.9352e-04 - val_loss: 4.8014e-04
# 132/132 [==============================] - 2s 10ms/step
# 33/33 [==============================] - 0s 10ms/step
# Epoch 1/100
# 132/132 [==============================] - 11s 42ms/step - loss: 0.0053 - val_loss: 0.0065
# Epoch 2/100
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0035 - val_loss: 0.0030
# Epoch 3/100
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 4/100
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0012 - val_loss: 6.4567e-04
# Epoch 5/100
# 132/132 [==============================] - 5s 35ms/step - loss: 7.0531e-04 - val_loss: 3.7215e-04
# Epoch 6/100
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0012 - val_loss: 1.3241e-04
# Epoch 7/100
# 132/132 [==============================] - 5s 36ms/step - loss: 5.3067e-04 - val_loss: 4.3049e-05
# Epoch 8/100
# 132/132 [==============================] - 5s 35ms/step - loss: 6.4859e-04 - val_loss: 4.4113e-05
# Epoch 9/100
# 132/132 [==============================] - 5s 35ms/step - loss: 6.2180e-04 - val_loss: 1.0647e-04
# Epoch 10/100
# 132/132 [==============================] - 5s 35ms/step - loss: 5.0838e-04 - val_loss: 1.7002e-04
# Epoch 11/100
# 132/132 [==============================] - 5s 35ms/step - loss: 5.0732e-04 - val_loss: 1.4850e-04
# Epoch 12/100
# 132/132 [==============================] - 5s 35ms/step - loss: 5.4822e-04 - val_loss: 2.1797e-04
# Epoch 13/100
# 132/132 [==============================] - 5s 35ms/step - loss: 5.1253e-04 - val_loss: 3.4331e-04
# Epoch 14/100
# 132/132 [==============================] - 5s 35ms/step - loss: 4.7072e-04 - val_loss: 3.1745e-04
# Epoch 15/100
# 132/132 [==============================] - 5s 35ms/step - loss: 4.6480e-04 - val_loss: 3.1336e-04
# Epoch 16/100
# 132/132 [==============================] - 5s 37ms/step - loss: 4.5902e-04 - val_loss: 3.5664e-04
# Epoch 17/100
# 132/132 [==============================] - 5s 35ms/step - loss: 4.4256e-04 - val_loss: 3.8444e-04
# 132/132 [==============================] - 2s 10ms/step
# 33/33 [==============================] - 0s 10ms/step
# Epoch 1/100
# 132/132 [==============================] - 15s 78ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 2/100
# 132/132 [==============================] - 9s 70ms/step - loss: 0.0082 - val_loss: 0.0047
# Epoch 3/100
# 132/132 [==============================] - 9s 70ms/step - loss: 0.0039 - val_loss: 0.0024
# Epoch 4/100
# 132/132 [==============================] - 9s 71ms/step - loss: 0.0022 - val_loss: 7.1857e-04
# Epoch 5/100
# 132/132 [==============================] - 9s 70ms/step - loss: 7.5321e-04 - val_loss: 6.9663e-05
# Epoch 6/100
# 132/132 [==============================] - 9s 70ms/step - loss: 4.8656e-04 - val_loss: 3.6675e-05
# Epoch 7/100
# 132/132 [==============================] - 9s 70ms/step - loss: 6.2267e-04 - val_loss: 6.8437e-05
# Epoch 8/100
# 132/132 [==============================] - 9s 70ms/step - loss: 5.1792e-04 - val_loss: 3.3692e-05
# Epoch 9/100
# 132/132 [==============================] - 9s 70ms/step - loss: 5.2305e-04 - val_loss: 3.7149e-05
# Epoch 10/100
# 132/132 [==============================] - 9s 70ms/step - loss: 5.3239e-04 - val_loss: 8.1544e-05
# Epoch 11/100
# 132/132 [==============================] - 9s 70ms/step - loss: 5.0307e-04 - val_loss: 1.6787e-04
# Epoch 12/100
# 132/132 [==============================] - 9s 71ms/step - loss: 4.8648e-04 - val_loss: 2.0712e-04
# Epoch 13/100
# 132/132 [==============================] - 9s 72ms/step - loss: 4.9109e-04 - val_loss: 2.3620e-04
# Epoch 14/100
# 132/132 [==============================] - 10s 72ms/step - loss: 4.9521e-04 - val_loss: 3.0257e-04
# Epoch 15/100
# 132/132 [==============================] - 9s 71ms/step - loss: 4.8308e-04 - val_loss: 3.5792e-04
# Epoch 16/100
# 132/132 [==============================] - 9s 70ms/step - loss: 4.6950e-04 - val_loss: 3.6910e-04
# Epoch 17/100
# 132/132 [==============================] - 9s 70ms/step - loss: 4.6304e-04 - val_loss: 3.7816e-04
# Epoch 18/100
# 132/132 [==============================] - 9s 70ms/step - loss: 4.5738e-04 - val_loss: 3.9705e-04
# 132/132 [==============================] - 3s 19ms/step
# 33/33 [==============================] - 1s 19ms/step
# Epoch 1/100
# 132/132 [==============================] - 8s 24ms/step - loss: 0.0061 - val_loss: 0.0036
# Epoch 2/100
# 132/132 [==============================] - 2s 18ms/step - loss: 0.0041 - val_loss: 0.0010
# Epoch 3/100
# 132/132 [==============================] - 2s 17ms/step - loss: 0.0020 - val_loss: 5.9441e-04
# Epoch 4/100
# 132/132 [==============================] - 2s 17ms/step - loss: 0.0014 - val_loss: 2.9403e-04
# Epoch 5/100
# 132/132 [==============================] - 2s 17ms/step - loss: 8.4919e-04 - val_loss: 4.0364e-04
# Epoch 6/100
# 132/132 [==============================] - 2s 17ms/step - loss: 0.0012 - val_loss: 2.6214e-04
# Epoch 7/100
# 132/132 [==============================] - 2s 17ms/step - loss: 7.7134e-04 - val_loss: 3.5634e-04
# Epoch 8/100
# 132/132 [==============================] - 2s 18ms/step - loss: 0.0011 - val_loss: 3.5667e-04
# Epoch 9/100
# 132/132 [==============================] - 2s 18ms/step - loss: 7.0696e-04 - val_loss: 3.6919e-04
# Epoch 10/100
# 132/132 [==============================] - 2s 17ms/step - loss: 0.0011 - val_loss: 4.3251e-04
# Epoch 11/100
# 132/132 [==============================] - 2s 18ms/step - loss: 6.4043e-04 - val_loss: 3.5729e-04
# Epoch 12/100
# 132/132 [==============================] - 2s 18ms/step - loss: 0.0010 - val_loss: 4.9326e-04
# Epoch 13/100
# 132/132 [==============================] - 2s 17ms/step - loss: 5.7657e-04 - val_loss: 3.2797e-04
# Epoch 14/100
# 132/132 [==============================] - 2s 18ms/step - loss: 9.0747e-04 - val_loss: 5.3657e-04
# Epoch 15/100
# 132/132 [==============================] - 2s 18ms/step - loss: 5.1072e-04 - val_loss: 2.8372e-04
# Epoch 16/100
# 132/132 [==============================] - 2s 18ms/step - loss: 7.7167e-04 - val_loss: 5.6320e-04
# 132/132 [==============================] - 1s 4ms/step
# 33/33 [==============================] - 0s 4ms/step
# Epoch 1/100
# 132/132 [==============================] - 13s 58ms/step - loss: 0.0057 - val_loss: 0.0099
# Epoch 2/100
# 132/132 [==============================] - 7s 51ms/step - loss: 0.0060 - val_loss: 0.0058
# Epoch 3/100
# 132/132 [==============================] - 7s 53ms/step - loss: 0.0023 - val_loss: 0.0010
# Epoch 4/100
# 132/132 [==============================] - 7s 53ms/step - loss: 8.1953e-04 - val_loss: 3.7647e-04
# Epoch 5/100
# 132/132 [==============================] - 7s 55ms/step - loss: 8.4625e-04 - val_loss: 3.8631e-04
# Epoch 6/100
# 132/132 [==============================] - 7s 53ms/step - loss: 6.6896e-04 - val_loss: 2.8092e-04
# Epoch 7/100
# 132/132 [==============================] - 7s 54ms/step - loss: 7.6245e-04 - val_loss: 1.8220e-04
# Epoch 8/100
# 132/132 [==============================] - 7s 53ms/step - loss: 5.8637e-04 - val_loss: 5.7576e-05
# Epoch 9/100
# 132/132 [==============================] - 7s 53ms/step - loss: 5.6558e-04 - val_loss: 3.5915e-05
# Epoch 10/100
# 132/132 [==============================] - 7s 52ms/step - loss: 5.6302e-04 - val_loss: 4.8565e-05
# Epoch 11/100
# 132/132 [==============================] - 7s 52ms/step - loss: 5.3251e-04 - val_loss: 1.0385e-04
# Epoch 12/100
# 132/132 [==============================] - 7s 52ms/step - loss: 5.0357e-04 - val_loss: 1.5233e-04
# Epoch 13/100
# 132/132 [==============================] - 7s 52ms/step - loss: 4.9937e-04 - val_loss: 1.8339e-04
# Epoch 14/100
# 132/132 [==============================] - 7s 52ms/step - loss: 4.9964e-04 - val_loss: 2.2800e-04
# Epoch 15/100
# 132/132 [==============================] - 7s 53ms/step - loss: 4.8527e-04 - val_loss: 2.7081e-04
# Epoch 16/100
# 132/132 [==============================] - 7s 54ms/step - loss: 4.6616e-04 - val_loss: 2.8498e-04
# Epoch 17/100
# 132/132 [==============================] - 8s 58ms/step - loss: 4.5649e-04 - val_loss: 2.9158e-04
# Epoch 18/100
# 132/132 [==============================] - 7s 56ms/step - loss: 4.4920e-04 - val_loss: 3.0331e-04
# Epoch 19/100
# 132/132 [==============================] - 7s 53ms/step - loss: 4.3875e-04 - val_loss: 3.1359e-04
# 132/132 [==============================] - 3s 13ms/step
# 33/33 [==============================] - 0s 13ms/step
# Epoch 1/100
# 132/132 [==============================] - 15s 73ms/step - loss: 0.0031 - val_loss: 0.0100
# Epoch 2/100
# 132/132 [==============================] - 9s 65ms/step - loss: 0.0110 - val_loss: 0.0100
# Epoch 3/100
# 132/132 [==============================] - 9s 65ms/step - loss: 0.0043 - val_loss: 0.0022
# Epoch 4/100
# 132/132 [==============================] - 9s 66ms/step - loss: 0.0019 - val_loss: 4.1895e-04
# Epoch 5/100
# 132/132 [==============================] - 9s 65ms/step - loss: 6.7388e-04 - val_loss: 6.5304e-05
# Epoch 6/100
# 132/132 [==============================] - 9s 65ms/step - loss: 4.5352e-04 - val_loss: 3.2773e-05
# Epoch 7/100
# 132/132 [==============================] - 9s 65ms/step - loss: 5.6209e-04 - val_loss: 4.9315e-05
# Epoch 8/100
# 132/132 [==============================] - 9s 65ms/step - loss: 4.4989e-04 - val_loss: 2.8997e-05
# Epoch 9/100
# 132/132 [==============================] - 9s 66ms/step - loss: 5.0210e-04 - val_loss: 3.0529e-05
# Epoch 10/100
# 132/132 [==============================] - 9s 66ms/step - loss: 5.1988e-04 - val_loss: 7.5579e-05
# Epoch 11/100
# 132/132 [==============================] - 9s 69ms/step - loss: 4.7172e-04 - val_loss: 1.8320e-04
# Epoch 12/100
# 132/132 [==============================] - 9s 71ms/step - loss: 4.5814e-04 - val_loss: 1.9160e-04
# Epoch 13/100
# 132/132 [==============================] - 9s 68ms/step - loss: 4.6866e-04 - val_loss: 1.8633e-04
# Epoch 14/100
# 132/132 [==============================] - 9s 66ms/step - loss: 4.8290e-04 - val_loss: 2.5205e-04
# Epoch 15/100
# 132/132 [==============================] - 9s 66ms/step - loss: 4.7156e-04 - val_loss: 3.3177e-04
# Epoch 16/100
# 132/132 [==============================] - 9s 66ms/step - loss: 4.5688e-04 - val_loss: 3.3993e-04
# Epoch 17/100
# 132/132 [==============================] - 9s 65ms/step - loss: 4.5218e-04 - val_loss: 3.3408e-04
# Epoch 18/100
# 132/132 [==============================] - 9s 64ms/step - loss: 4.5027e-04 - val_loss: 3.5114e-04
# 132/132 [==============================] - 3s 18ms/step
# 33/33 [==============================] - 1s 17ms/step
# Epoch 1/100
# 132/132 [==============================] - 10s 39ms/step - loss: 0.0054 - val_loss: 0.0063
# Epoch 2/100
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0037 - val_loss: 0.0026
# Epoch 3/100
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 4/100
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0012 - val_loss: 7.2545e-04
# Epoch 5/100
# 132/132 [==============================] - 4s 32ms/step - loss: 8.0005e-04 - val_loss: 5.3711e-04
# Epoch 6/100
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0012 - val_loss: 1.6669e-04
# Epoch 7/100
# 132/132 [==============================] - 4s 32ms/step - loss: 5.3673e-04 - val_loss: 3.8225e-05
# Epoch 8/100
# 132/132 [==============================] - 4s 32ms/step - loss: 6.3724e-04 - val_loss: 5.6303e-05
# Epoch 9/100
# 132/132 [==============================] - 4s 33ms/step - loss: 7.1178e-04 - val_loss: 6.8480e-05
# Epoch 10/100
# 132/132 [==============================] - 4s 34ms/step - loss: 5.3350e-04 - val_loss: 1.7981e-04
# Epoch 11/100
# 132/132 [==============================] - 5s 34ms/step - loss: 4.9777e-04 - val_loss: 1.6590e-04
# Epoch 12/100
# 132/132 [==============================] - 5s 35ms/step - loss: 5.2730e-04 - val_loss: 1.6707e-04
# Epoch 13/100
# 132/132 [==============================] - 4s 32ms/step - loss: 5.4496e-04 - val_loss: 2.6067e-04
# Epoch 14/100
# 132/132 [==============================] - 4s 32ms/step - loss: 4.9598e-04 - val_loss: 3.2757e-04
# Epoch 15/100
# 132/132 [==============================] - 4s 32ms/step - loss: 4.6910e-04 - val_loss: 2.8467e-04
# Epoch 16/100
# 132/132 [==============================] - 4s 32ms/step - loss: 4.7112e-04 - val_loss: 2.9589e-04
# Epoch 17/100
# 132/132 [==============================] - 4s 32ms/step - loss: 4.6264e-04 - val_loss: 3.1291e-04
# 132/132 [==============================] - 2s 9ms/step
# 33/33 [==============================] - 0s 9ms/step
# Epoch 1/100
# 132/132 [==============================] - 8s 25ms/step - loss: 0.0057 - val_loss: 0.0022
# Epoch 2/100
# 132/132 [==============================] - 2s 18ms/step - loss: 0.0030 - val_loss: 9.3109e-04
# Epoch 3/100
# 132/132 [==============================] - 2s 18ms/step - loss: 0.0018 - val_loss: 4.7329e-04
# Epoch 4/100
# 132/132 [==============================] - 2s 18ms/step - loss: 0.0012 - val_loss: 3.3625e-04
# Epoch 5/100
# 132/132 [==============================] - 2s 18ms/step - loss: 9.7382e-04 - val_loss: 4.6744e-04
# Epoch 6/100
# 132/132 [==============================] - 2s 18ms/step - loss: 0.0012 - val_loss: 3.4941e-04
# Epoch 7/100
# 132/132 [==============================] - 2s 19ms/step - loss: 6.9989e-04 - val_loss: 1.2137e-04
# Epoch 8/100
# 132/132 [==============================] - 2s 19ms/step - loss: 8.4537e-04 - val_loss: 2.6725e-04
# Epoch 9/100
# 132/132 [==============================] - 2s 18ms/step - loss: 7.2837e-04 - val_loss: 1.2060e-04
# Epoch 10/100
# 132/132 [==============================] - 2s 18ms/step - loss: 6.0606e-04 - val_loss: 6.5718e-05
# Epoch 11/100
# 132/132 [==============================] - 2s 19ms/step - loss: 6.1504e-04 - val_loss: 7.2829e-05
# Epoch 12/100
# 132/132 [==============================] - 3s 20ms/step - loss: 6.5543e-04 - val_loss: 7.7832e-05
# Epoch 13/100
# 132/132 [==============================] - 3s 19ms/step - loss: 5.3694e-04 - val_loss: 8.6994e-05
# Epoch 14/100
# 132/132 [==============================] - 2s 19ms/step - loss: 5.1848e-04 - val_loss: 7.8984e-05
# Epoch 15/100
# 132/132 [==============================] - 3s 23ms/step - loss: 5.2157e-04 - val_loss: 6.2911e-05
# Epoch 16/100
# 132/132 [==============================] - 3s 23ms/step - loss: 4.8238e-04 - val_loss: 1.1150e-04
# Epoch 17/100
# 132/132 [==============================] - 3s 21ms/step - loss: 4.8086e-04 - val_loss: 9.0891e-05
# Epoch 18/100
# 132/132 [==============================] - 3s 20ms/step - loss: 4.5013e-04 - val_loss: 1.1407e-04
# Epoch 19/100
# 132/132 [==============================] - 3s 20ms/step - loss: 4.5160e-04 - val_loss: 1.0418e-04
# Epoch 20/100
# 132/132 [==============================] - 3s 20ms/step - loss: 4.2880e-04 - val_loss: 1.1099e-04
# Epoch 21/100
# 132/132 [==============================] - 2s 19ms/step - loss: 4.3387e-04 - val_loss: 1.0079e-04
# Epoch 22/100
# 132/132 [==============================] - 2s 19ms/step - loss: 4.0933e-04 - val_loss: 1.1200e-04
# Epoch 23/100
# 132/132 [==============================] - 2s 18ms/step - loss: 4.3300e-04 - val_loss: 8.7318e-05
# Epoch 24/100
# 132/132 [==============================] - 2s 18ms/step - loss: 3.8634e-04 - val_loss: 1.2941e-04
# Epoch 25/100
# 132/132 [==============================] - 2s 18ms/step - loss: 4.9153e-04 - val_loss: 4.6939e-05
# Epoch 26/100
# 132/132 [==============================] - 2s 18ms/step - loss: 3.4429e-04 - val_loss: 2.2971e-04
# Epoch 27/100
# 132/132 [==============================] - 2s 18ms/step - loss: 6.7944e-04 - val_loss: 7.0537e-05
# Epoch 28/100
# 132/132 [==============================] - 2s 18ms/step - loss: 3.4547e-04 - val_loss: 3.2119e-04
# Epoch 29/100
# 132/132 [==============================] - 2s 18ms/step - loss: 6.4525e-04 - val_loss: 2.4181e-04
# Epoch 30/100
# 132/132 [==============================] - 2s 18ms/step - loss: 5.7245e-04 - val_loss: 1.7725e-04
# Epoch 31/100
# 132/132 [==============================] - 2s 18ms/step - loss: 4.8719e-04 - val_loss: 6.6437e-05
# Epoch 32/100
# 132/132 [==============================] - 2s 18ms/step - loss: 3.3620e-04 - val_loss: 3.8359e-05
# Epoch 33/100
# 132/132 [==============================] - 2s 18ms/step - loss: 3.1563e-04 - val_loss: 4.2167e-05
# Epoch 34/100
# 132/132 [==============================] - 2s 18ms/step - loss: 3.0330e-04 - val_loss: 4.5985e-05
# Epoch 35/100
# 132/132 [==============================] - 3s 19ms/step - loss: 3.0892e-04 - val_loss: 4.3510e-05
# Epoch 36/100
# 132/132 [==============================] - 2s 18ms/step - loss: 3.1815e-04 - val_loss: 3.8935e-05
# Epoch 37/100
# 132/132 [==============================] - 2s 18ms/step - loss: 3.2814e-04 - val_loss: 3.5576e-05
# Epoch 38/100
# 132/132 [==============================] - 2s 18ms/step - loss: 3.3190e-04 - val_loss: 3.3385e-05
# Epoch 39/100
# 132/132 [==============================] - 2s 18ms/step - loss: 3.2493e-04 - val_loss: 3.1826e-05
# Epoch 40/100
# 132/132 [==============================] - 3s 19ms/step - loss: 3.2530e-04 - val_loss: 3.3003e-05
# Epoch 41/100
# 132/132 [==============================] - 2s 18ms/step - loss: 3.4264e-04 - val_loss: 5.3511e-05
# Epoch 42/100
# 132/132 [==============================] - 2s 18ms/step - loss: 3.8646e-04 - val_loss: 9.9731e-05
# Epoch 43/100
# 132/132 [==============================] - 2s 18ms/step - loss: 4.4799e-04 - val_loss: 1.2884e-04
# Epoch 44/100
# 132/132 [==============================] - 2s 18ms/step - loss: 5.0529e-04 - val_loss: 1.3090e-04
# Epoch 45/100
# 132/132 [==============================] - 2s 18ms/step - loss: 5.5408e-04 - val_loss: 3.9810e-05
# Epoch 46/100
# 132/132 [==============================] - 2s 18ms/step - loss: 3.4295e-04 - val_loss: 3.4896e-05
# Epoch 47/100
# 132/132 [==============================] - 2s 18ms/step - loss: 3.3638e-04 - val_loss: 1.6656e-04
# Epoch 48/100
# 132/132 [==============================] - 2s 18ms/step - loss: 2.4257e-04 - val_loss: 6.7278e-05
# Epoch 49/100
# 132/132 [==============================] - 2s 18ms/step - loss: 3.1569e-04 - val_loss: 1.2397e-04
# 132/132 [==============================] - 2s 5ms/step
# 33/33 [==============================] - 0s 5ms/step
# Generation: 1
# Best Fitness: 0.0001239690988722563
# Best Individual: [0.14490614 0.17333493 0.48406214 0.1811115  0.59665809]
# ----------------------
# Epoch 1/100
# 132/132 [==============================] - 8s 25ms/step - loss: 0.0043 - val_loss: 0.0024
# Epoch 2/100
# 132/132 [==============================] - 2s 18ms/step - loss: 0.0022 - val_loss: 0.0012
# Epoch 3/100
# 132/132 [==============================] - 2s 18ms/step - loss: 0.0015 - val_loss: 6.7944e-04
# Epoch 4/100
# 132/132 [==============================] - 2s 18ms/step - loss: 9.9820e-04 - val_loss: 5.8004e-04
# Epoch 5/100
# 132/132 [==============================] - 2s 18ms/step - loss: 0.0010 - val_loss: 5.2602e-04
# Epoch 6/100
# 132/132 [==============================] - 2s 18ms/step - loss: 7.6042e-04 - val_loss: 2.5192e-04
# Epoch 7/100
# 132/132 [==============================] - 2s 18ms/step - loss: 7.7466e-04 - val_loss: 2.1109e-04
# Epoch 8/100
# 132/132 [==============================] - 2s 18ms/step - loss: 6.7060e-04 - val_loss: 1.1042e-04
# Epoch 9/100
# 132/132 [==============================] - 2s 18ms/step - loss: 6.2753e-04 - val_loss: 7.9448e-05
# Epoch 10/100
# 132/132 [==============================] - 2s 18ms/step - loss: 6.1326e-04 - val_loss: 6.6657e-05
# Epoch 11/100
# 132/132 [==============================] - 2s 18ms/step - loss: 5.8509e-04 - val_loss: 6.1120e-05
# Epoch 12/100
# 132/132 [==============================] - 2s 18ms/step - loss: 5.5488e-04 - val_loss: 6.4269e-05
# Epoch 13/100
# 132/132 [==============================] - 2s 18ms/step - loss: 5.3647e-04 - val_loss: 7.2546e-05
# Epoch 14/100
# 132/132 [==============================] - 2s 18ms/step - loss: 5.1941e-04 - val_loss: 8.4068e-05
# Epoch 15/100
# 132/132 [==============================] - 2s 18ms/step - loss: 5.0023e-04 - val_loss: 9.1027e-05
# Epoch 16/100
# 132/132 [==============================] - 2s 19ms/step - loss: 4.8308e-04 - val_loss: 1.0168e-04
# Epoch 17/100
# 132/132 [==============================] - 2s 18ms/step - loss: 4.7513e-04 - val_loss: 8.1828e-05
# Epoch 18/100
# 132/132 [==============================] - 2s 18ms/step - loss: 4.6346e-04 - val_loss: 6.7631e-05
# Epoch 19/100
# 132/132 [==============================] - 2s 18ms/step - loss: 4.3524e-04 - val_loss: 4.0000e-05
# Epoch 20/100
# 132/132 [==============================] - 2s 18ms/step - loss: 4.6709e-04 - val_loss: 4.1819e-05
# Epoch 21/100
# 132/132 [==============================] - 2s 18ms/step - loss: 5.5410e-04 - val_loss: 8.0324e-05
# Epoch 22/100
# 132/132 [==============================] - 2s 18ms/step - loss: 4.0374e-04 - val_loss: 5.2829e-05
# Epoch 23/100
# 132/132 [==============================] - 2s 18ms/step - loss: 3.6247e-04 - val_loss: 9.6906e-05
# Epoch 24/100
# 132/132 [==============================] - 2s 18ms/step - loss: 4.0986e-04 - val_loss: 5.9140e-05
# Epoch 25/100
# 132/132 [==============================] - 2s 18ms/step - loss: 3.3549e-04 - val_loss: 3.0922e-05
# Epoch 26/100
# 132/132 [==============================] - 2s 18ms/step - loss: 3.2189e-04 - val_loss: 5.8982e-05
# Epoch 27/100
# 132/132 [==============================] - 2s 18ms/step - loss: 3.5625e-04 - val_loss: 4.8755e-05
# Epoch 28/100
# 132/132 [==============================] - 2s 19ms/step - loss: 3.5449e-04 - val_loss: 2.9101e-04
# Epoch 29/100
# 132/132 [==============================] - 2s 19ms/step - loss: 6.5377e-04 - val_loss: 4.0134e-05
# Epoch 30/100
# 132/132 [==============================] - 2s 19ms/step - loss: 3.3441e-04 - val_loss: 5.4882e-05
# Epoch 31/100
# 132/132 [==============================] - 2s 18ms/step - loss: 3.5749e-04 - val_loss: 4.5773e-05
# Epoch 32/100
# 132/132 [==============================] - 2s 18ms/step - loss: 3.3565e-04 - val_loss: 8.3087e-05
# Epoch 33/100
# 132/132 [==============================] - 2s 19ms/step - loss: 3.8538e-04 - val_loss: 5.9375e-05
# Epoch 34/100
# 132/132 [==============================] - 2s 18ms/step - loss: 3.0424e-04 - val_loss: 1.0161e-04
# Epoch 35/100
# 132/132 [==============================] - 2s 18ms/step - loss: 4.2895e-04 - val_loss: 6.6639e-05
# 132/132 [==============================] - 2s 5ms/step
# 33/33 [==============================] - 0s 4ms/step
# Epoch 1/100
# 132/132 [==============================] - 10s 40ms/step - loss: 0.0049 - val_loss: 0.0068
# Epoch 2/100
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0038 - val_loss: 0.0032
# Epoch 3/100
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 4/100
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0012 - val_loss: 7.9295e-04
# Epoch 5/100
# 132/132 [==============================] - 4s 33ms/step - loss: 7.3379e-04 - val_loss: 6.1860e-04
# Epoch 6/100
# 132/132 [==============================] - 5s 34ms/step - loss: 0.0011 - val_loss: 4.1649e-04
# Epoch 7/100
# 132/132 [==============================] - 4s 34ms/step - loss: 5.4535e-04 - val_loss: 9.4465e-05
# Epoch 8/100
# 132/132 [==============================] - 4s 32ms/step - loss: 6.5293e-04 - val_loss: 1.2571e-04
# Epoch 9/100
# 132/132 [==============================] - 4s 32ms/step - loss: 7.1383e-04 - val_loss: 4.8764e-05
# Epoch 10/100
# 132/132 [==============================] - 4s 32ms/step - loss: 5.0121e-04 - val_loss: 9.6365e-05
# Epoch 11/100
# 132/132 [==============================] - 4s 34ms/step - loss: 4.6077e-04 - val_loss: 9.7924e-05
# Epoch 12/100
# 132/132 [==============================] - 4s 32ms/step - loss: 5.1498e-04 - val_loss: 9.2032e-05
# Epoch 13/100
# 132/132 [==============================] - 4s 32ms/step - loss: 5.5219e-04 - val_loss: 2.2631e-04
# Epoch 14/100
# 132/132 [==============================] - 4s 32ms/step - loss: 4.5593e-04 - val_loss: 2.9767e-04
# Epoch 15/100
# 132/132 [==============================] - 4s 32ms/step - loss: 4.4189e-04 - val_loss: 2.4407e-04
# Epoch 16/100
# 132/132 [==============================] - 4s 32ms/step - loss: 4.5832e-04 - val_loss: 2.6170e-04
# Epoch 17/100
# 132/132 [==============================] - 4s 32ms/step - loss: 4.5588e-04 - val_loss: 3.3684e-04
# Epoch 18/100
# 132/132 [==============================] - 4s 33ms/step - loss: 4.2744e-04 - val_loss: 3.3574e-04
# Epoch 19/100
# 132/132 [==============================] - 4s 34ms/step - loss: 4.2106e-04 - val_loss: 3.2822e-04
# 132/132 [==============================] - 2s 9ms/step
# 33/33 [==============================] - 0s 9ms/step
# Epoch 1/100
# 132/132 [==============================] - 14s 65ms/step - loss: 0.0059 - val_loss: 0.0070
# Epoch 2/100
# 132/132 [==============================] - 8s 59ms/step - loss: 0.0051 - val_loss: 0.0055
# Epoch 3/100
# 132/132 [==============================] - 8s 59ms/step - loss: 0.0021 - val_loss: 0.0011
# Epoch 4/100
# 132/132 [==============================] - 8s 57ms/step - loss: 7.4195e-04 - val_loss: 7.4061e-04
# Epoch 5/100
# 132/132 [==============================] - 7s 56ms/step - loss: 0.0012 - val_loss: 7.4545e-04
# Epoch 6/100
# 132/132 [==============================] - 7s 55ms/step - loss: 5.3590e-04 - val_loss: 3.3581e-04
# Epoch 7/100
# 132/132 [==============================] - 7s 56ms/step - loss: 8.7247e-04 - val_loss: 5.1247e-04
# Epoch 8/100
# 132/132 [==============================] - 7s 56ms/step - loss: 6.3818e-04 - val_loss: 2.2043e-04
# Epoch 9/100
# 132/132 [==============================] - 7s 56ms/step - loss: 6.2563e-04 - val_loss: 9.2987e-05
# Epoch 10/100
# 132/132 [==============================] - 7s 56ms/step - loss: 5.4525e-04 - val_loss: 3.2293e-05
# Epoch 11/100
# 132/132 [==============================] - 7s 56ms/step - loss: 4.8934e-04 - val_loss: 5.0375e-05
# Epoch 12/100
# 132/132 [==============================] - 7s 57ms/step - loss: 4.7978e-04 - val_loss: 7.7951e-05
# Epoch 13/100
# 132/132 [==============================] - 8s 60ms/step - loss: 4.9609e-04 - val_loss: 1.1563e-04
# Epoch 14/100
# 132/132 [==============================] - 8s 61ms/step - loss: 4.9694e-04 - val_loss: 1.7893e-04
# Epoch 15/100
# 132/132 [==============================] - 8s 59ms/step - loss: 4.7100e-04 - val_loss: 2.3262e-04
# Epoch 16/100
# 132/132 [==============================] - 7s 56ms/step - loss: 4.5292e-04 - val_loss: 2.5164e-04
# Epoch 17/100
# 132/132 [==============================] - 8s 58ms/step - loss: 4.5279e-04 - val_loss: 2.7105e-04
# Epoch 18/100
# 132/132 [==============================] - 8s 57ms/step - loss: 4.5079e-04 - val_loss: 3.0024e-04
# Epoch 19/100
# 132/132 [==============================] - 8s 57ms/step - loss: 4.3827e-04 - val_loss: 3.2207e-04
# Epoch 20/100
# 132/132 [==============================] - 8s 61ms/step - loss: 4.2554e-04 - val_loss: 3.2959e-04
# 132/132 [==============================] - 3s 16ms/step
# 33/33 [==============================] - 1s 16ms/step
# Epoch 1/100
# 132/132 [==============================] - 11s 42ms/step - loss: 0.0054 - val_loss: 0.0072
# Epoch 2/100
# 132/132 [==============================] - 5s 34ms/step - loss: 0.0038 - val_loss: 0.0034
# Epoch 3/100
# 132/132 [==============================] - 5s 34ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 4/100
# 132/132 [==============================] - 5s 36ms/step - loss: 0.0012 - val_loss: 8.7068e-04
# Epoch 5/100
# 132/132 [==============================] - 5s 35ms/step - loss: 9.0016e-04 - val_loss: 6.1810e-04
# Epoch 6/100
# 132/132 [==============================] - 5s 34ms/step - loss: 0.0010 - val_loss: 2.5456e-04
# Epoch 7/100
# 132/132 [==============================] - 5s 34ms/step - loss: 6.1324e-04 - val_loss: 6.5272e-05
# Epoch 8/100
# 132/132 [==============================] - 5s 34ms/step - loss: 6.6563e-04 - val_loss: 5.2232e-05
# Epoch 9/100
# 132/132 [==============================] - 5s 34ms/step - loss: 7.4118e-04 - val_loss: 9.6346e-05
# Epoch 10/100
# 132/132 [==============================] - 5s 34ms/step - loss: 5.3638e-04 - val_loss: 1.5125e-04
# Epoch 11/100
# 132/132 [==============================] - 5s 34ms/step - loss: 5.4192e-04 - val_loss: 9.2767e-05
# Epoch 12/100
# 132/132 [==============================] - 5s 34ms/step - loss: 6.3581e-04 - val_loss: 2.4178e-04
# Epoch 13/100
# 132/132 [==============================] - 5s 34ms/step - loss: 5.3318e-04 - val_loss: 3.8468e-04
# Epoch 14/100
# 132/132 [==============================] - 5s 34ms/step - loss: 5.0718e-04 - val_loss: 2.6015e-04
# Epoch 15/100
# 132/132 [==============================] - 5s 37ms/step - loss: 5.1429e-04 - val_loss: 3.4517e-04
# Epoch 16/100
# 132/132 [==============================] - 5s 38ms/step - loss: 4.9090e-04 - val_loss: 4.3454e-04
# Epoch 17/100
# 132/132 [==============================] - 5s 36ms/step - loss: 4.7383e-04 - val_loss: 3.9528e-04
# Epoch 18/100
# 132/132 [==============================] - 5s 35ms/step - loss: 4.6289e-04 - val_loss: 4.0399e-04
# 132/132 [==============================] - 2s 9ms/step
# 33/33 [==============================] - 0s 9ms/step
# Epoch 1/100
# 132/132 [==============================] - 17s 88ms/step - loss: 0.0039 - val_loss: 0.0103
# Epoch 2/100
# 132/132 [==============================] - 10s 77ms/step - loss: 0.0095 - val_loss: 0.0099
# Epoch 3/100
# 132/132 [==============================] - 10s 79ms/step - loss: 0.0045 - val_loss: 0.0023
# Epoch 4/100
# 132/132 [==============================] - 10s 77ms/step - loss: 0.0019 - val_loss: 4.0268e-04
# Epoch 5/100
# 132/132 [==============================] - 10s 76ms/step - loss: 6.2882e-04 - val_loss: 5.8527e-05
# Epoch 6/100
# 132/132 [==============================] - 10s 78ms/step - loss: 4.3256e-04 - val_loss: 3.1130e-05
# Epoch 7/100
# 132/132 [==============================] - 10s 77ms/step - loss: 5.3726e-04 - val_loss: 4.9396e-05
# Epoch 8/100
# 132/132 [==============================] - 10s 77ms/step - loss: 4.3720e-04 - val_loss: 2.7142e-05
# Epoch 9/100
# 132/132 [==============================] - 10s 76ms/step - loss: 4.9307e-04 - val_loss: 3.1895e-05
# Epoch 10/100
# 132/132 [==============================] - 10s 78ms/step - loss: 5.0059e-04 - val_loss: 4.4640e-05
# Epoch 11/100
# 132/132 [==============================] - 10s 77ms/step - loss: 4.6755e-04 - val_loss: 1.0915e-04
# Epoch 12/100
# 132/132 [==============================] - 10s 77ms/step - loss: 4.5483e-04 - val_loss: 1.5095e-04
# Epoch 13/100
# 132/132 [==============================] - 10s 77ms/step - loss: 4.6060e-04 - val_loss: 1.7614e-04
# Epoch 14/100
# 132/132 [==============================] - 10s 77ms/step - loss: 4.6837e-04 - val_loss: 2.2597e-04
# Epoch 15/100
# 132/132 [==============================] - 10s 78ms/step - loss: 4.6524e-04 - val_loss: 2.8577e-04
# Epoch 16/100
# 132/132 [==============================] - 10s 76ms/step - loss: 4.5605e-04 - val_loss: 3.1855e-04
# Epoch 17/100
# 132/132 [==============================] - 10s 76ms/step - loss: 4.4909e-04 - val_loss: 3.3026e-04
# Epoch 18/100
# 132/132 [==============================] - 10s 77ms/step - loss: 4.4404e-04 - val_loss: 3.4123e-04
# 132/132 [==============================] - 4s 20ms/step
# 33/33 [==============================] - 1s 20ms/step
# Epoch 1/100
# 132/132 [==============================] - 10s 40ms/step - loss: 0.0057 - val_loss: 0.0078
# Epoch 2/100
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0044 - val_loss: 0.0037
# Epoch 3/100
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0020 - val_loss: 9.1221e-04
# Epoch 4/100
# 132/132 [==============================] - 4s 32ms/step - loss: 8.3223e-04 - val_loss: 7.5180e-04
# Epoch 5/100
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0014 - val_loss: 5.8695e-04
# Epoch 6/100
# 132/132 [==============================] - 4s 32ms/step - loss: 5.6232e-04 - val_loss: 1.9145e-04
# Epoch 7/100
# 132/132 [==============================] - 4s 32ms/step - loss: 9.5552e-04 - val_loss: 3.9200e-04
# Epoch 8/100
# 132/132 [==============================] - 4s 33ms/step - loss: 6.0919e-04 - val_loss: 1.0399e-04
# Epoch 9/100
# 132/132 [==============================] - 4s 33ms/step - loss: 6.0511e-04 - val_loss: 5.6464e-05
# Epoch 10/100
# 132/132 [==============================] - 4s 33ms/step - loss: 5.8998e-04 - val_loss: 4.6594e-05
# Epoch 11/100
# 132/132 [==============================] - 4s 33ms/step - loss: 5.2370e-04 - val_loss: 1.0548e-04
# Epoch 12/100
# 132/132 [==============================] - 4s 34ms/step - loss: 4.9003e-04 - val_loss: 1.3988e-04
# Epoch 13/100
# 132/132 [==============================] - 4s 32ms/step - loss: 5.0101e-04 - val_loss: 1.6535e-04
# Epoch 14/100
# 132/132 [==============================] - 4s 33ms/step - loss: 5.0074e-04 - val_loss: 2.2801e-04
# Epoch 15/100
# 132/132 [==============================] - 5s 34ms/step - loss: 4.7399e-04 - val_loss: 2.8544e-04
# Epoch 16/100
# 132/132 [==============================] - 4s 34ms/step - loss: 4.5239e-04 - val_loss: 2.7765e-04
# Epoch 17/100
# 132/132 [==============================] - 4s 33ms/step - loss: 4.5003e-04 - val_loss: 2.9582e-04
# Epoch 18/100
# 132/132 [==============================] - 4s 33ms/step - loss: 4.3988e-04 - val_loss: 3.0507e-04
# Epoch 19/100
# 132/132 [==============================] - 4s 34ms/step - loss: 4.2602e-04 - val_loss: 3.2947e-04
# Epoch 20/100
# 132/132 [==============================] - 4s 34ms/step - loss: 4.1381e-04 - val_loss: 2.9956e-04
# 132/132 [==============================] - 2s 9ms/step
# 33/33 [==============================] - 0s 9ms/step
# Epoch 1/100
# 132/132 [==============================] - 14s 64ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 2/100
# 132/132 [==============================] - 7s 56ms/step - loss: 0.0039 - val_loss: 0.0038
# Epoch 3/100
# 132/132 [==============================] - 7s 56ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 4/100
# 132/132 [==============================] - 7s 55ms/step - loss: 0.0011 - val_loss: 8.3985e-04
# Epoch 5/100
# 132/132 [==============================] - 7s 55ms/step - loss: 7.9580e-04 - val_loss: 5.8243e-04
# Epoch 6/100
# 132/132 [==============================] - 7s 56ms/step - loss: 9.7341e-04 - val_loss: 3.2345e-04
# Epoch 7/100
# 132/132 [==============================] - 7s 56ms/step - loss: 5.9865e-04 - val_loss: 8.0547e-05
# Epoch 8/100
# 132/132 [==============================] - 7s 56ms/step - loss: 6.2731e-04 - val_loss: 4.3461e-05
# Epoch 9/100
# 132/132 [==============================] - 7s 55ms/step - loss: 6.0955e-04 - val_loss: 4.7454e-05
# Epoch 10/100
# 132/132 [==============================] - 7s 56ms/step - loss: 5.3636e-04 - val_loss: 1.1445e-04
# Epoch 11/100
# 132/132 [==============================] - 8s 59ms/step - loss: 5.0600e-04 - val_loss: 1.4366e-04
# Epoch 12/100
# 132/132 [==============================] - 8s 57ms/step - loss: 5.2804e-04 - val_loss: 1.6856e-04
# Epoch 13/100
# 132/132 [==============================] - 7s 57ms/step - loss: 5.3278e-04 - val_loss: 2.4121e-04
# Epoch 14/100
# 132/132 [==============================] - 7s 56ms/step - loss: 4.9080e-04 - val_loss: 2.9058e-04
# Epoch 15/100
# 132/132 [==============================] - 7s 55ms/step - loss: 4.6809e-04 - val_loss: 2.8327e-04
# Epoch 16/100
# 132/132 [==============================] - 8s 59ms/step - loss: 4.7277e-04 - val_loss: 2.9412e-04
# Epoch 17/100
# 132/132 [==============================] - 8s 59ms/step - loss: 4.6780e-04 - val_loss: 3.2487e-04
# Epoch 18/100
# 132/132 [==============================] - 7s 57ms/step - loss: 4.4621e-04 - val_loss: 3.3799e-04
# 132/132 [==============================] - 3s 15ms/step
# 33/33 [==============================] - 1s 16ms/step
# Epoch 1/100
# 132/132 [==============================] - 11s 44ms/step - loss: 0.0055 - val_loss: 0.0072
# Epoch 2/100
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0038 - val_loss: 0.0036
# Epoch 3/100
# 132/132 [==============================] - 5s 38ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 4/100
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0014 - val_loss: 8.6007e-04
# Epoch 5/100
# 132/132 [==============================] - 5s 35ms/step - loss: 6.6989e-04 - val_loss: 3.8766e-04
# Epoch 6/100
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0011 - val_loss: 3.7046e-04
# Epoch 7/100
# 132/132 [==============================] - 5s 36ms/step - loss: 6.2266e-04 - val_loss: 8.0121e-05
# Epoch 8/100
# 132/132 [==============================] - 5s 34ms/step - loss: 6.3533e-04 - val_loss: 5.5702e-05
# Epoch 9/100
# 132/132 [==============================] - 5s 36ms/step - loss: 6.6610e-04 - val_loss: 4.2688e-05
# Epoch 10/100
# 132/132 [==============================] - 5s 35ms/step - loss: 5.6931e-04 - val_loss: 1.1126e-04
# Epoch 11/100
# 132/132 [==============================] - 5s 35ms/step - loss: 5.0772e-04 - val_loss: 1.2981e-04
# Epoch 12/100
# 132/132 [==============================] - 5s 34ms/step - loss: 5.3537e-04 - val_loss: 1.3189e-04
# Epoch 13/100
# 132/132 [==============================] - 5s 35ms/step - loss: 5.6022e-04 - val_loss: 2.2824e-04
# Epoch 14/100
# 132/132 [==============================] - 4s 34ms/step - loss: 4.9359e-04 - val_loss: 3.0051e-04
# Epoch 15/100
# 132/132 [==============================] - 5s 34ms/step - loss: 4.6241e-04 - val_loss: 2.5596e-04
# Epoch 16/100
# 132/132 [==============================] - 5s 34ms/step - loss: 4.7236e-04 - val_loss: 2.6747e-04
# Epoch 17/100
# 132/132 [==============================] - 4s 34ms/step - loss: 4.6894e-04 - val_loss: 3.1264e-04
# Epoch 18/100
# 132/132 [==============================] - 4s 34ms/step - loss: 4.3919e-04 - val_loss: 3.2578e-04
# Epoch 19/100
# 132/132 [==============================] - 5s 36ms/step - loss: 4.2586e-04 - val_loss: 3.0049e-04
# 132/132 [==============================] - 2s 10ms/step
# 33/33 [==============================] - 0s 10ms/step
# Epoch 1/100
# 132/132 [==============================] - 17s 88ms/step - loss: 0.0035 - val_loss: 0.0122
# Epoch 2/100
# 132/132 [==============================] - 10s 78ms/step - loss: 0.0101 - val_loss: 0.0098
# Epoch 3/100
# 132/132 [==============================] - 11s 80ms/step - loss: 0.0045 - val_loss: 0.0026
# Epoch 4/100
# 132/132 [==============================] - 11s 83ms/step - loss: 0.0018 - val_loss: 4.7312e-04
# Epoch 5/100
# 132/132 [==============================] - 11s 87ms/step - loss: 6.0066e-04 - val_loss: 4.6382e-05
# Epoch 6/100
# 132/132 [==============================] - 10s 80ms/step - loss: 4.3398e-04 - val_loss: 5.4946e-05
# Epoch 7/100
# 132/132 [==============================] - 11s 80ms/step - loss: 5.6575e-04 - val_loss: 7.1366e-05
# Epoch 8/100
# 132/132 [==============================] - 10s 78ms/step - loss: 4.6418e-04 - val_loss: 2.8706e-05
# Epoch 9/100
# 132/132 [==============================] - 10s 78ms/step - loss: 4.7144e-04 - val_loss: 2.9418e-05
# Epoch 10/100
# 132/132 [==============================] - 10s 78ms/step - loss: 4.8961e-04 - val_loss: 5.8796e-05
# Epoch 11/100
# 132/132 [==============================] - 10s 78ms/step - loss: 4.7234e-04 - val_loss: 1.3624e-04
# Epoch 12/100
# 132/132 [==============================] - 10s 78ms/step - loss: 4.5538e-04 - val_loss: 1.8186e-04
# Epoch 13/100
# 132/132 [==============================] - 10s 78ms/step - loss: 4.6003e-04 - val_loss: 1.9771e-04
# Epoch 14/100
# 132/132 [==============================] - 10s 78ms/step - loss: 4.7240e-04 - val_loss: 2.4900e-04
# Epoch 15/100
# 132/132 [==============================] - 10s 79ms/step - loss: 4.6871e-04 - val_loss: 3.1603e-04
# Epoch 16/100
# 132/132 [==============================] - 11s 81ms/step - loss: 4.5456e-04 - val_loss: 3.3698e-04
# Epoch 17/100
# 132/132 [==============================] - 11s 83ms/step - loss: 4.4822e-04 - val_loss: 3.3969e-04
# Epoch 18/100
# 132/132 [==============================] - 11s 82ms/step - loss: 4.4670e-04 - val_loss: 3.5857e-04
# 132/132 [==============================] - 5s 25ms/step
# 33/33 [==============================] - 1s 23ms/step
# Epoch 1/100
# 132/132 [==============================] - 9s 34ms/step - loss: 0.0055 - val_loss: 0.0021
# Epoch 2/100
# 132/132 [==============================] - 2s 19ms/step - loss: 0.0029 - val_loss: 9.8635e-04
# Epoch 3/100
# 132/132 [==============================] - 2s 19ms/step - loss: 0.0019 - val_loss: 4.8362e-04
# Epoch 4/100
# 132/132 [==============================] - 2s 19ms/step - loss: 0.0012 - val_loss: 2.5529e-04
# Epoch 5/100
# 132/132 [==============================] - 2s 19ms/step - loss: 9.0453e-04 - val_loss: 2.9041e-04
# Epoch 6/100
# 132/132 [==============================] - 2s 18ms/step - loss: 0.0011 - val_loss: 2.4024e-04
# Epoch 7/100
# 132/132 [==============================] - 2s 19ms/step - loss: 7.5061e-04 - val_loss: 7.4462e-05
# Epoch 8/100
# 132/132 [==============================] - 2s 19ms/step - loss: 7.9328e-04 - val_loss: 1.7154e-04
# Epoch 9/100
# 132/132 [==============================] - 2s 19ms/step - loss: 7.3800e-04 - val_loss: 1.0083e-04
# Epoch 10/100
# 132/132 [==============================] - 2s 19ms/step - loss: 6.7635e-04 - val_loss: 7.7388e-05
# Epoch 11/100
# 132/132 [==============================] - 3s 19ms/step - loss: 6.5732e-04 - val_loss: 7.4668e-05
# Epoch 12/100
# 132/132 [==============================] - 2s 18ms/step - loss: 6.5062e-04 - val_loss: 7.7206e-05
# Epoch 13/100
# 132/132 [==============================] - 3s 21ms/step - loss: 6.2004e-04 - val_loss: 8.6794e-05
# Epoch 14/100
# 132/132 [==============================] - 3s 19ms/step - loss: 6.0115e-04 - val_loss: 8.9229e-05
# Epoch 15/100
# 132/132 [==============================] - 2s 19ms/step - loss: 5.8560e-04 - val_loss: 9.1301e-05
# Epoch 16/100
# 132/132 [==============================] - 3s 20ms/step - loss: 5.7153e-04 - val_loss: 1.0306e-04
# Epoch 17/100
# 132/132 [==============================] - 2s 19ms/step - loss: 5.7119e-04 - val_loss: 1.1199e-04
# 132/132 [==============================] - 2s 5ms/step
# 33/33 [==============================] - 0s 5ms/step
# Generation: 2
# Best Fitness: 6.663946300260012e-05
# Best Individual: [0.14490614 0.17333493 0.48406214 0.1811115  0.59665809]
# ----------------------
# Epoch 1/100
# 132/132 [==============================] - 9s 29ms/step - loss: 0.0073 - val_loss: 0.0045
# Epoch 2/100
# 132/132 [==============================] - 2s 18ms/step - loss: 0.0036 - val_loss: 8.9594e-04
# Epoch 3/100
# 132/132 [==============================] - 2s 18ms/step - loss: 0.0018 - val_loss: 3.3762e-04
# Epoch 4/100
# 132/132 [==============================] - 3s 19ms/step - loss: 0.0012 - val_loss: 2.5836e-04
# Epoch 5/100
# 132/132 [==============================] - 2s 19ms/step - loss: 9.7655e-04 - val_loss: 3.2073e-04
# Epoch 6/100
# ...
# Epoch 11/100
# 132/132 [==============================] - 4s 33ms/step - loss: 6.1997e-04 - val_loss: 7.4990e-05
# Epoch 12/100
# 132/132 [==============================] - 5s 40ms/step - loss: 5.9939e-04 - val_loss: 7.0048e-05
# Epoch 13/100
# 132/132 [==============================] - 4s 32ms/step - loss: 5.9241e-04 - val_loss: 7.7871e-05
# Epoch 14/100
# 132/132 [==============================] - 4s 32ms/step - loss: 5.6632e-04 - val_loss: 7.4802e-05
# Epoch 15/100
# 132/132 [==============================] - 5s 39ms/step - loss: 5.5500e-04 - val_loss: 1.2112e-04
# Epoch 16/100
# 132/132 [==============================] - 5s 38ms/step - loss: 5.3704e-04 - val_loss: 2.1234e-04
# Epoch 17/100
# 132/132 [==============================] - 5s 36ms/step - loss: 5.2589e-04 - val_loss: 2.1885e-04
# Epoch 18/100
# 132/132 [==============================] - 5s 36ms/step - loss: 5.1267e-04 - val_loss: 2.0259e-04
# Epoch 19/100
# 132/132 [==============================] - 5s 36ms/step - loss: 4.8732e-04 - val_loss: 1.7823e-04
# Epoch 20/100
# 132/132 [==============================] - 5s 37ms/step - loss: 4.6978e-04 - val_loss: 1.5761e-04
# Epoch 21/100
# 132/132 [==============================] - 5s 35ms/step - loss: 4.5403e-04 - val_loss: 1.4333e-04
# Epoch 22/100
# 132/132 [==============================] - 5s 37ms/step - loss: 4.4255e-04 - val_loss: 1.3517e-04
# 132/132 [==============================] - 11s 11ms/step
# 33/33 [==============================] - 0s 11ms/step
# Epoch 1/100
# 132/132 [==============================] - 46s 76ms/step - loss: 0.0048 - val_loss: 0.0050
# Epoch 2/100
# 132/132 [==============================] - 7s 51ms/step - loss: 0.0038 - val_loss: 0.0034
# Epoch 3/100
# 132/132 [==============================] - 7s 51ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 4/100
# 132/132 [==============================] - 7s 51ms/step - loss: 0.0013 - val_loss: 7.5659e-04
# Epoch 5/100
# 132/132 [==============================] - 7s 56ms/step - loss: 6.6832e-04 - val_loss: 4.7415e-04
# Epoch 6/100
# 132/132 [==============================] - 8s 57ms/step - loss: 0.0012 - val_loss: 3.2535e-04
# Epoch 7/100
# 132/132 [==============================] - 7s 56ms/step - loss: 5.4177e-04 - val_loss: 6.2098e-05
# Epoch 8/100
# 132/132 [==============================] - 8s 64ms/step - loss: 6.7784e-04 - val_loss: 1.0674e-04
# Epoch 9/100
# 132/132 [==============================] - 9s 65ms/step - loss: 6.6287e-04 - val_loss: 4.7208e-05
# Epoch 10/100
# 132/132 [==============================] - 9s 66ms/step - loss: 5.3255e-04 - val_loss: 1.2173e-04
# Epoch 11/100
# 132/132 [==============================] - 9s 68ms/step - loss: 4.9532e-04 - val_loss: 1.3901e-04
# Epoch 12/100
# 132/132 [==============================] - 9s 67ms/step - loss: 5.2188e-04 - val_loss: 1.6827e-04
# Epoch 13/100
# 132/132 [==============================] - 9s 67ms/step - loss: 5.2620e-04 - val_loss: 2.8953e-04
# Epoch 14/100
# 132/132 [==============================] - 9s 66ms/step - loss: 4.7392e-04 - val_loss: 3.5816e-04
# Epoch 15/100
# 132/132 [==============================] - 9s 68ms/step - loss: 4.5989e-04 - val_loss: 3.1846e-04
# Epoch 16/100
# 132/132 [==============================] - 8s 63ms/step - loss: 4.5720e-04 - val_loss: 3.5560e-04
# Epoch 17/100
# 132/132 [==============================] - 8s 58ms/step - loss: 4.4837e-04 - val_loss: 3.7490e-04
# Epoch 18/100
# 132/132 [==============================] - 8s 57ms/step - loss: 4.2964e-04 - val_loss: 3.9303e-04
# Epoch 19/100
# 132/132 [==============================] - 7s 54ms/step - loss: 4.2820e-04 - val_loss: 3.5433e-04
# 132/132 [==============================] - 6s 16ms/step
# 33/33 [==============================] - 1s 16ms/step
# Epoch 1/100
# 132/132 [==============================] - 23s 51ms/step - loss: 0.0050 - val_loss: 0.0024
# Epoch 2/100
# 132/132 [==============================] - 4s 29ms/step - loss: 0.0027 - val_loss: 0.0015
# Epoch 3/100
# 132/132 [==============================] - 4s 29ms/step - loss: 0.0020 - val_loss: 0.0012
# Epoch 4/100
# 132/132 [==============================] - 4s 29ms/step - loss: 0.0015 - val_loss: 8.2152e-04
# Epoch 5/100
# 132/132 [==============================] - 4s 30ms/step - loss: 0.0011 - val_loss: 6.7897e-04
# Epoch 6/100
# 132/132 [==============================] - 4s 31ms/step - loss: 8.8560e-04 - val_loss: 7.1215e-04
# Epoch 7/100
# 132/132 [==============================] - 4s 31ms/step - loss: 8.9940e-04 - val_loss: 5.7496e-04
# Epoch 8/100
# 132/132 [==============================] - 5s 35ms/step - loss: 7.0441e-04 - val_loss: 3.2742e-04
# Epoch 9/100
# 132/132 [==============================] - 5s 40ms/step - loss: 6.6309e-04 - val_loss: 2.4699e-04
# Epoch 10/100
# 132/132 [==============================] - 4s 30ms/step - loss: 5.9666e-04 - val_loss: 1.4576e-04
# Epoch 11/100
# 132/132 [==============================] - 4s 31ms/step - loss: 5.5907e-04 - val_loss: 1.0591e-04
# Epoch 12/100
# 132/132 [==============================] - 5s 36ms/step - loss: 5.3791e-04 - val_loss: 9.7451e-05
# Epoch 13/100
# 132/132 [==============================] - 5s 37ms/step - loss: 5.5316e-04 - val_loss: 1.5526e-04
# Epoch 14/100
# 132/132 [==============================] - 5s 38ms/step - loss: 6.0929e-04 - val_loss: 1.3345e-04
# Epoch 15/100
# 132/132 [==============================] - 5s 39ms/step - loss: 4.9642e-04 - val_loss: 8.5918e-05
# Epoch 16/100
# 132/132 [==============================] - 5s 36ms/step - loss: 4.6312e-04 - val_loss: 1.2092e-04
# Epoch 17/100
# 132/132 [==============================] - 5s 37ms/step - loss: 4.4791e-04 - val_loss: 7.8004e-05
# Epoch 18/100
# 132/132 [==============================] - 5s 36ms/step - loss: 4.1755e-04 - val_loss: 4.9502e-05
# Epoch 19/100
# 132/132 [==============================] - 5s 38ms/step - loss: 4.0748e-04 - val_loss: 4.4653e-05
# Epoch 20/100
# 132/132 [==============================] - 5s 37ms/step - loss: 4.0111e-04 - val_loss: 4.4900e-05
# Epoch 21/100
# 132/132 [==============================] - 5s 36ms/step - loss: 3.9386e-04 - val_loss: 4.5521e-05
# Epoch 22/100
# 132/132 [==============================] - 5s 39ms/step - loss: 3.7880e-04 - val_loss: 4.0999e-05
# Epoch 23/100
# 132/132 [==============================] - 5s 37ms/step - loss: 3.9779e-04 - val_loss: 5.2259e-05
# Epoch 24/100
# 132/132 [==============================] - 5s 35ms/step - loss: 4.5336e-04 - val_loss: 5.4033e-05
# Epoch 25/100
# 132/132 [==============================] - 4s 29ms/step - loss: 3.8346e-04 - val_loss: 4.4059e-05
# Epoch 26/100
# 132/132 [==============================] - 4s 31ms/step - loss: 3.4440e-04 - val_loss: 1.1226e-04
# Epoch 27/100
# 132/132 [==============================] - 5s 35ms/step - loss: 4.4291e-04 - val_loss: 6.4295e-05
# Epoch 28/100
# 132/132 [==============================] - 4s 31ms/step - loss: 3.6191e-04 - val_loss: 9.9139e-05
# Epoch 29/100
# 132/132 [==============================] - 4s 30ms/step - loss: 4.1517e-04 - val_loss: 7.3971e-05
# Epoch 30/100
# 132/132 [==============================] - 4s 29ms/step - loss: 3.7208e-04 - val_loss: 8.7739e-05
# Epoch 31/100
# 132/132 [==============================] - 4s 29ms/step - loss: 4.0043e-04 - val_loss: 7.5651e-05
# Epoch 32/100
# 132/132 [==============================] - 4s 29ms/step - loss: 3.7979e-04 - val_loss: 7.9023e-05
# 132/132 [==============================] - 6s 8ms/step
# 33/33 [==============================] - 0s 8ms/step
# Epoch 1/100
# 132/132 [==============================] - 63s 203ms/step - loss: 0.0066 - val_loss: 0.0078
# Epoch 2/100
# 132/132 [==============================] - 19s 141ms/step - loss: 0.0049 - val_loss: 0.0043
# Epoch 3/100
# 132/132 [==============================] - 19s 142ms/step - loss: 0.0019 - val_loss: 8.5664e-04
# Epoch 4/100
# 132/132 [==============================] - 19s 142ms/step - loss: 6.7322e-04 - val_loss: 7.0153e-04
# Epoch 5/100
# 132/132 [==============================] - 16s 124ms/step - loss: 0.0016 - val_loss: 3.8173e-04
# Epoch 6/100
# 132/132 [==============================] - 15s 115ms/step - loss: 5.1645e-04 - val_loss: 7.0456e-05
# Epoch 7/100
# 132/132 [==============================] - 14s 109ms/step - loss: 7.6370e-04 - val_loss: 1.9264e-04
# Epoch 8/100
# 132/132 [==============================] - 15s 110ms/step - loss: 7.3795e-04 - val_loss: 4.2666e-05
# Epoch 9/100
# 132/132 [==============================] - 15s 115ms/step - loss: 5.1993e-04 - val_loss: 1.1867e-04
# Epoch 10/100
# 132/132 [==============================] - 17s 126ms/step - loss: 4.8353e-04 - val_loss: 1.1034e-04
# Epoch 11/100
# 132/132 [==============================] - 18s 134ms/step - loss: 5.4586e-04 - val_loss: 1.3364e-04
# Epoch 12/100
# 132/132 [==============================] - 18s 136ms/step - loss: 5.8825e-04 - val_loss: 3.6275e-04
# Epoch 13/100
# 132/132 [==============================] - 18s 135ms/step - loss: 4.8788e-04 - val_loss: 3.9640e-04
# Epoch 14/100
# 132/132 [==============================] - 13s 98ms/step - loss: 4.7576e-04 - val_loss: 2.9112e-04
# Epoch 15/100
# 132/132 [==============================] - 12s 92ms/step - loss: 5.0249e-04 - val_loss: 3.6375e-04
# Epoch 16/100
# 132/132 [==============================] - 13s 101ms/step - loss: 4.9456e-04 - val_loss: 4.6093e-04
# Epoch 17/100
# 132/132 [==============================] - 16s 124ms/step - loss: 4.5738e-04 - val_loss: 4.2550e-04
# Epoch 18/100
# 132/132 [==============================] - 14s 103ms/step - loss: 4.5813e-04 - val_loss: 3.8772e-04
# 132/132 [==============================] - 9s 41ms/step
# 33/33 [==============================] - 1s 42ms/step
# Epoch 1/100
# 132/132 [==============================] - 47s 102ms/step - loss: 0.0040 - val_loss: 0.0015
# Epoch 2/100
# 132/132 [==============================] - 5s 35ms/step - loss: 0.0017 - val_loss: 3.3632e-04
# Epoch 3/100
# 132/132 [==============================] - 5s 36ms/step - loss: 0.0011 - val_loss: 2.7364e-04
# Epoch 4/100
# 132/132 [==============================] - 5s 36ms/step - loss: 0.0014 - val_loss: 2.9315e-04
# Epoch 5/100
# 132/132 [==============================] - 5s 36ms/step - loss: 0.0010 - val_loss: 8.2027e-05
# Epoch 6/100
# 132/132 [==============================] - 5s 35ms/step - loss: 8.0435e-04 - val_loss: 1.2273e-04
# Epoch 7/100
# 132/132 [==============================] - 5s 35ms/step - loss: 7.3308e-04 - val_loss: 8.8465e-05
# Epoch 8/100
# 132/132 [==============================] - 5s 36ms/step - loss: 6.9898e-04 - val_loss: 8.7959e-05
# Epoch 9/100
# 132/132 [==============================] - 5s 36ms/step - loss: 6.7671e-04 - val_loss: 8.9417e-05
# Epoch 10/100
# 132/132 [==============================] - 5s 36ms/step - loss: 6.5691e-04 - val_loss: 1.0283e-04
# Epoch 11/100
# 132/132 [==============================] - 5s 35ms/step - loss: 6.3689e-04 - val_loss: 1.2251e-04
# Epoch 12/100
# 132/132 [==============================] - 5s 36ms/step - loss: 6.1942e-04 - val_loss: 1.3717e-04
# Epoch 13/100
# 132/132 [==============================] - 5s 35ms/step - loss: 6.0232e-04 - val_loss: 1.4894e-04
# Epoch 14/100
# 132/132 [==============================] - 5s 35ms/step - loss: 5.8629e-04 - val_loss: 1.5980e-04
# Epoch 15/100
# 132/132 [==============================] - 5s 36ms/step - loss: 5.7190e-04 - val_loss: 1.6857e-04
# 132/132 [==============================] - 4s 8ms/step
# 33/33 [==============================] - 0s 9ms/step
# Epoch 1/100
# 132/132 [==============================] - 28s 122ms/step - loss: 0.0035 - val_loss: 0.0112
# Epoch 2/100
# 132/132 [==============================] - 14s 107ms/step - loss: 0.0089 - val_loss: 0.0096
# Epoch 3/100
# 132/132 [==============================] - 14s 107ms/step - loss: 0.0036 - val_loss: 0.0021
# Epoch 4/100
# 132/132 [==============================] - 14s 105ms/step - loss: 0.0015 - val_loss: 2.6552e-04
# Epoch 5/100
# 132/132 [==============================] - 11s 83ms/step - loss: 5.9798e-04 - val_loss: 4.4791e-05
# Epoch 6/100
# 132/132 [==============================] - 11s 80ms/step - loss: 5.0710e-04 - val_loss: 4.9928e-05
# Epoch 7/100
# 132/132 [==============================] - 11s 80ms/step - loss: 5.6874e-04 - val_loss: 6.4890e-05
# Epoch 8/100
# 132/132 [==============================] - 11s 81ms/step - loss: 5.5746e-04 - val_loss: 4.3805e-05
# Epoch 9/100
# 132/132 [==============================] - 9s 71ms/step - loss: 4.9657e-04 - val_loss: 7.3849e-05
# Epoch 10/100
# 132/132 [==============================] - 10s 72ms/step - loss: 4.8629e-04 - val_loss: 8.6057e-05
# Epoch 11/100
# 132/132 [==============================] - 10s 76ms/step - loss: 5.0380e-04 - val_loss: 1.2037e-04
# Epoch 12/100
# 132/132 [==============================] - 10s 77ms/step - loss: 4.9849e-04 - val_loss: 2.1897e-04
# Epoch 13/100
# 132/132 [==============================] - 12s 89ms/step - loss: 4.7352e-04 - val_loss: 2.7669e-04
# Epoch 14/100
# 132/132 [==============================] - 12s 92ms/step - loss: 4.6652e-04 - val_loss: 2.6902e-04
# Epoch 15/100
# 132/132 [==============================] - 13s 96ms/step - loss: 4.6735e-04 - val_loss: 2.8716e-04
# Epoch 16/100
# 132/132 [==============================] - 13s 96ms/step - loss: 4.6053e-04 - val_loss: 3.2890e-04
# Epoch 17/100
# 132/132 [==============================] - 13s 96ms/step - loss: 4.4635e-04 - val_loss: 3.4291e-04
# Epoch 18/100
# 132/132 [==============================] - 13s 98ms/step - loss: 4.3681e-04 - val_loss: 3.3901e-04
# 132/132 [==============================] - 10s 31ms/step
# 33/33 [==============================] - 1s 32ms/step
# Epoch 1/100
# 132/132 [==============================] - 38s 75ms/step - loss: 0.0054 - val_loss: 0.0065
# Epoch 2/100
# 132/132 [==============================] - 6s 46ms/step - loss: 0.0034 - val_loss: 0.0028
# Epoch 3/100
# 132/132 [==============================] - 6s 46ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 4/100
# 132/132 [==============================] - 6s 47ms/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 5/100
# 132/132 [==============================] - 6s 47ms/step - loss: 6.0872e-04 - val_loss: 6.2413e-04
# Epoch 6/100
# 132/132 [==============================] - 6s 47ms/step - loss: 0.0014 - val_loss: 6.1299e-04
# Epoch 7/100
# 132/132 [==============================] - 7s 54ms/step - loss: 5.1872e-04 - val_loss: 1.3856e-04
# Epoch 8/100
# 132/132 [==============================] - 7s 52ms/step - loss: 7.6569e-04 - val_loss: 2.4891e-04
# Epoch 9/100
# 132/132 [==============================] - 7s 54ms/step - loss: 7.0453e-04 - val_loss: 7.1097e-05
# Epoch 10/100
# 132/132 [==============================] - 8s 58ms/step - loss: 4.9045e-04 - val_loss: 6.3343e-05
# Epoch 11/100
# 132/132 [==============================] - 8s 58ms/step - loss: 4.5369e-04 - val_loss: 7.3392e-05
# Epoch 12/100
# 132/132 [==============================] - 8s 57ms/step - loss: 5.0572e-04 - val_loss: 6.0751e-05
# Epoch 13/100
# 132/132 [==============================] - 8s 57ms/step - loss: 5.4667e-04 - val_loss: 1.2437e-04
# Epoch 14/100
# 132/132 [==============================] - 8s 58ms/step - loss: 4.6696e-04 - val_loss: 2.2718e-04
# Epoch 15/100
# 132/132 [==============================] - 8s 59ms/step - loss: 4.2996e-04 - val_loss: 1.9942e-04
# Epoch 16/100
# 132/132 [==============================] - 8s 58ms/step - loss: 4.5660e-04 - val_loss: 1.5674e-04
# Epoch 17/100
# 132/132 [==============================] - 8s 58ms/step - loss: 5.0429e-04 - val_loss: 1.8044e-04
# Epoch 18/100
# 132/132 [==============================] - 8s 59ms/step - loss: 4.7544e-04 - val_loss: 2.2777e-04
# Epoch 19/100
# 132/132 [==============================] - 8s 57ms/step - loss: 4.2649e-04 - val_loss: 3.6167e-04
# Epoch 20/100
# 132/132 [==============================] - 8s 59ms/step - loss: 3.8432e-04 - val_loss: 3.2976e-04
# Epoch 21/100
# 132/132 [==============================] - 8s 58ms/step - loss: 3.8997e-04 - val_loss: 2.8721e-04
# Epoch 22/100
# 132/132 [==============================] - 8s 58ms/step - loss: 3.9220e-04 - val_loss: 3.0015e-04
# 132/132 [==============================] - 8s 14ms/step
# 33/33 [==============================] - 1s 15ms/step
# Generation: 10
# Best Fitness: 7.902269235911538e-05
# Best Individual: [0.14490614 0.17333493 0.48406214 0.89894598 0.59665809]
# ----------------------
# Final Result:
# Best Fitness: 5.167731550025934e-05
# Best Individual: [0.14490614 0.24038835 0.48406214 0.1811115  0.59665809]

# %%
# Create the BiLSTM model using the optimized input parameters
model = Sequential()
model.add(Bidirectional(LSTM(units=lstm_units, return_sequences=True), input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Bidirectional(LSTM(units=lstm_units)))
model.add(Dense(1))
model.compile(loss='mse', optimizer='adam')

# Train and evaluate the model with the new parameters
model, history, train_predictions, test_predictions = fit_model(model, X_train, y_train, X_test, y_test)
loss = model.evaluate(X_test, y_test)
print('Model loss:', loss)
# Out:
# Epoch 1/100
# 132/132 [==============================] - 19s 62ms/step - loss: 0.0067 - val_loss: 0.0036
# Epoch 2/100
# 132/132 [==============================] - 3s 26ms/step - loss: 0.0041 - val_loss: 6.0572e-04
# Epoch 3/100
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0016 - val_loss: 2.5545e-04
# Epoch 4/100
# 132/132 [==============================] - 4s 32ms/step - loss: 0.0011 - val_loss: 1.4270e-04
# Epoch 5/100
# 132/132 [==============================] - 4s 32ms/step - loss: 8.3553e-04 - val_loss: 2.4147e-04
# Epoch 6/100
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0012 - val_loss: 1.9677e-04
# Epoch 7/100
# 132/132 [==============================] - 4s 32ms/step - loss: 8.4115e-04 - val_loss: 1.2610e-04
# Epoch 8/100
# 132/132 [==============================] - 4s 33ms/step - loss: 0.0011 - val_loss: 2.5147e-04
# Epoch 9/100
# 132/132 [==============================] - 4s 32ms/step - loss: 6.6716e-04 - val_loss: 1.0507e-04
# Epoch 10/100
# 132/132 [==============================] - 4s 32ms/step - loss: 9.5618e-04 - val_loss: 1.9757e-04
# Epoch 11/100
# 132/132 [==============================] - 4s 32ms/step - loss: 6.0904e-04 - val_loss: 7.0689e-05
# Epoch 12/100
# 132/132 [==============================] - 4s 32ms/step - loss: 7.8023e-04 - val_loss: 1.5475e-04
# Epoch 13/100
# 132/132 [==============================] - 4s 32ms/step - loss: 5.3235e-04 - val_loss: 5.0548e-05
# Epoch 14/100
# 132/132 [==============================] - 4s 33ms/step - loss: 5.7335e-04 - val_loss: 7.2622e-05
# Epoch 15/100
# 132/132 [==============================] - 4s 32ms/step - loss: 5.2298e-04 - val_loss: 6.4332e-05
# Epoch 16/100
# 132/132 [==============================] - 4s 32ms/step - loss: 4.9213e-04 - val_loss: 6.2627e-05
# Epoch 17/100
# 132/132 [==============================] - 4s 32ms/step - loss: 4.9219e-04 - val_loss: 5.6880e-05
# Epoch 18/100
# 132/132 [==============================] - 4s 30ms/step - loss: 4.8371e-04 - val_loss: 6.7166e-05
# Epoch 19/100
# 132/132 [==============================] - 3s 26ms/step - loss: 4.7036e-04 - val_loss: 7.4515e-05
# Epoch 20/100
# 132/132 [==============================] - 4s 28ms/step - loss: 4.6178e-04 - val_loss: 7.0722e-05
# Epoch 21/100
# 132/132 [==============================] - 3s 26ms/step - loss: 4.5613e-04 - val_loss: 7.3864e-05
# Epoch 22/100
# 132/132 [==============================] - 3s 26ms/step - loss: 4.5026e-04 - val_loss: 8.0369e-05
# Epoch 23/100
# 132/132 [==============================] - 3s 24ms/step - loss: 4.5499e-04 - val_loss: 8.7205e-05
# 132/132 [==============================] - 3s 6ms/step
# 33/33 [==============================] - 0s 5ms/step
# 33/33 [==============================] - 0s 6ms/step - loss: 8.7205e-05
# Model loss: 8.720489131519571e-05

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error


# Inverse transform the normalized predictions and true values
train_predictions = scaler_y.inverse_transform(train_predictions)
test_predictions = scaler_y.inverse_transform(test_predictions)
y_train_true = scaler_y.inverse_transform(y_train)
y_test_true = scaler_y.inverse_transform(y_test)

# Calculate the mean squared error
train_mse = mean_squared_error(y_train_true, train_predictions)
test_mse = mean_squared_error(y_test_true, test_predictions)

# Calculate mean absolute error
train_mae = mean_absolute_error(y_train_true, train_predictions)
test_mae = mean_absolute_error(y_test_true, test_predictions)

# Calculate root mean squared error
train_rmse = np.sqrt(train_mse)
test_rmse = np.sqrt(test_mse)

# Calculate accuracy measure (e.g., R-squared score)
train_r2 = r2_score(y_train_true, train_predictions)
test_r2 = r2_score(y_test_true, test_predictions)

# %%
import matplotlib.pyplot as plt

# Plot the true future and predicted values
plt.figure(figsize=(12, 6))
plt.plot(y_test_true, label='True Future')
plt.plot(test_predictions, label='Predicted Future')
plt.title('ICICI BANK')
plt.xlabel('Time')
plt.ylabel('Open Price')
plt.legend()
plt.show()

print('Train MSE:', train_mse)
print('Test MSE:', test_mse)
print('Train MAE:', train_mae)
print('Test MAE:', test_mae)
print('Train RMSE:', train_rmse)
print('Test RMSE:', test_rmse)
print('Train R-squared:', train_r2)
print('Test R-squared:', test_r2)
# Out:
# Train MSE: 0.0008791397604396733
# Test MSE: 8.720489940673338e-05
# Train MAE: 0.019831563484830044
# Test MAE: 0.006778699753910986
# Train RMSE: 0.02965029106838031
# Test RMSE: 0.009338356354666134
# Train R-squared: 0.983910309022597
# Test R-squared: 0.9718005016940104

# %%
# Plotting the time series data
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Open'], label='Open Price')
plt.xlabel('Date')
plt.ylabel('Normalized Open Price')
plt.title('Time Series - Open Price')
plt.legend()
plt.show()
